# %% [markdown]
# # Ingest Results files (multi json)

# %%
# %run ../00-common/01.enviroment-config

# %%
# %run ../00-common/02.bronze-helpers

# %%
source_path = f'{landing_folder_path}/results'
table_name = f'{catalog_name}.{bronze_schema}.results'

# %%
from pyspark.sql.types import StructField, StructType, StringType, DateType, DoubleType, IntegerType

results_schema = StructType([
    StructField('date', DateType()),
    StructField('raceName', StringType()),
    StructField('round', IntegerType()),
    StructField('season', IntegerType()),
    StructField('url', StringType()),
    StructField('constructorId', StringType()),
    StructField('driverId', StringType()),
    StructField('grid', IntegerType()),
    StructField('laps', IntegerType()),
    StructField('number', IntegerType()),
    StructField('points', DoubleType()),
    StructField('position', IntegerType()),
    StructField('positionText', StringType()),
    StructField('status', StringType())
])

# %%
results_df = (
    spark.read
        .format('JSON')
        .schema(results_schema)
        .load(source_path)
)

# %%
display(results_df)

# %%
results_df_final = add_ingestion_metadata(results_df)

# %%
(
    results_df_final.write
        .format('delta')
        .mode('overwrite')
        .saveAsTable(table_name)
)

# %%
# %sql
SELECT * FROM formula1.bronze.results
