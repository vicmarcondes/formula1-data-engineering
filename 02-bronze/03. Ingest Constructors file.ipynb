# %% [markdown]
# # Ingest Constructors file (JSON)

# %%
dbutils.widgets.text('p_batch_id', '')

# %%
v_batch_id = dbutils.widgets.get('p_batch_id')
v_batch_id

# %%
# %run ../00-common/01.environment-config

# %%
# %run ../00-common/02.bronze-helpers

# %%
source_path = f'{landing_folder_path}/{v_batch_id}/constructors.json'
table_name = f'{catalog_name}.{bronze_schema}.constructors'

# %%
constructors_schema = 'constructorId STRING, name STRING, nationality STRING, url STRING' ## DDL String

# %%
constructors_df = (
    spark.read
        .format('json')
        .schema(constructors_schema)
        .load(source_path)
)

# %%
display(constructors_df)

# %%
constructors_df_final = add_ingestion_metadata(constructors_df)

# %%
display(constructors_df_final)

# %%
# %sql
DROP TABLE formula1.bronze.constructors

# %%
write_to_bronze (
    final_df = constructors_df_final,
    target_table = table_name,
    batch_id = v_batch_id
)

# %%
# (
#     constructors_df_final.write
#         .format('delta')
#         .mode('overwrite')
#         .saveAsTable(table_name)
# )

# %%
# %sql
SELECT * FROM formula1.bronze.constructors
